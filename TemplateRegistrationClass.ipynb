# %%
import os
import shutil
from pathlib import Path
import json
import nibabel as nib
import numpy as np
import glob
import ants
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
############### SLICE 3

# Ruta raíz desde donde buscar
root_dir = r"C:\Users\cvzad\Documents\CirugiaBariatrica"

# Buscar todos los archivos que terminan con 'T2w_masked.nii.gz' en cualquier subcarpeta
pattern = os.path.join(root_dir, '**', '*T2w_masked.nii.gz')
T2w_files = glob.glob(pattern, recursive=True)

# Lista para guardar los slices
population_sl3 = []

for file in T2w_files:
    try:
        file = os.path.normpath(file)
        img = ants.image_read(file)
        slice_3 = img[:, :, 2]
        population_sl3.append(slice_3)

    except Exception as e:
        print(e)
        print(f"Error al cargar archivo: {file}")

# Crear el template desde los slices 2D
if population_sl3:
    T2w_template_mice_sl3 = ants.build_template(initial_template=None, image_list=population_sl3)
else:
    print("No se pudieron cargar imágenes para crear el template.")
# Out:
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl2_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl3_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl3_final_test\sub-A090425_R109_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl5_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl2_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl3_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl3_final_test\sub-D270325_R110_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl5_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl2_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl3_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl5_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl2_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl3_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl5_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl2_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl3_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl5_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl2_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl3_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl5_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl2_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl3_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl5_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl2_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl3_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl5_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl2_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl3_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl5_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl2_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl3_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl5_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl2_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl3_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl5_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl2_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl3_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl5_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl2_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl3_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl5_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl2_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl3_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# Too many indices for image
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl5_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpd_k6k2v4.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0013\\out0GenericAffine.mat']
# 0.030439775
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpsei1jz6b.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0013\\out0GenericAffine.mat']
# 0.0056579085
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpmwmkef_g.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpfv5nlfwq\\img0013\\out0GenericAffine.mat']
# 0.0034460907

# %%
T2w_template_mice_sl3.plot()

# %%
############### SLICE 2

# Lista para guardar los slices
population_sl2 = []

for file in T2w_files:
    try:
        file = os.path.normpath(file)
        img = ants.image_read(file)
        slice_2 = img[:, :, 1]
        population_sl2.append(slice_2)

    except Exception as e:
        print(f"Error al cargar archivo: {file}")

# Crear el template desde los slices 2D
if population_sl2:
    T2w_template_mice_sl2 = ants.build_template(initial_template=None, image_list=population_sl2)
else:
    print("No se pudieron cargar imágenes para crear el template.")
# Out:
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl2_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl3_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl3_final_test\sub-A090425_R109_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl5_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl2_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl3_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl3_final_test\sub-D270325_R110_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl5_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl2_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl3_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl5_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl2_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl3_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl5_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl2_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl3_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl5_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl2_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl3_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl5_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl2_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl3_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl5_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl2_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl3_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl5_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl2_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl3_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl5_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl2_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl3_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl5_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl2_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl3_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl5_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl2_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl3_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl5_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl2_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl3_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl5_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl2_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl3_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl5_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmp6bq6puj0.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0013\\out0GenericAffine.mat']
# 0.02377607
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmp2exp_xb6.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0013\\out0GenericAffine.mat']
# 0.0052600005
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmp5hu0cnht.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmphnc0_kdp\\img0013\\out0GenericAffine.mat']
# 0.0031011556

# %%
T2w_template_mice_sl2.plot()

# %%
################ slice 5
# Lista para guardar los slices
population_sl5 = []

for file in T2w_files:
    try:
        file = os.path.normpath(file)
        img = ants.image_read(file)
        slice_5 = img[:, :, 4]
        population_sl5.append(slice_5)

    except Exception as e:
        print(f"Error al cargar archivo: {file}")

# Crear el template desde los slices 2D
if population_sl5:
    T2w_template_mice_sl5 = ants.build_template(initial_template=None, image_list=population_sl5)
else:
    print("No se pudieron cargar imágenes para crear el template.")
# Out:
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl2_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl3_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl3_final_test\sub-A090425_R109_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\corregistered_sl5_final_test\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl2_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl3_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl3_final_test\sub-D270325_R110_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\corregistered_sl5_final_test\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl2_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl3_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\corregistered_sl5_final_test\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl2_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl3_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\corregistered_sl5_final_test\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl2_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl3_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R113\resomapper_output\corregistered_sl5_final_test\sub-B090425_R113_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl2_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl3_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R159\resomapper_output\corregistered_sl5_final_test\sub-C090425_R159_CirugiaBar_Post_6w_090425_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl2_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl3_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R160\resomapper_output\corregistered_sl5_final_test\sub-D090425_R160_CirugiaBar_Post_6W_090425_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl2_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl3_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R109\resomapper_output\corregistered_sl5_final_test\sub-A270125_R109_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl2_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl3_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R110\resomapper_output\corregistered_sl5_final_test\sub-G200125_R110_CirugiaBar_Pre_3_200125_acq-2_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl2_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl3_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R111\resomapper_output\corregistered_sl5_final_test\sub-D200125_R111_CirugiaBar_Pre_200125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl2_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl3_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R112\resomapper_output\corregistered_sl5_final_test\sub-B270125_R112_CirugiaBar_Pre_270125_acq-4_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl2_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl3_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\corregistered_sl5_final_test\sub-C270125_R113_CirugiaBar_Pre_270125_acq-6_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl2_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl3_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\corregistered_sl5_final_test\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl2_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl3_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# Error al cargar archivo: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\corregistered_sl5_final_test\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmp3yrijcys.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0013\\out0GenericAffine.mat']
# 0.01812997
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpbz_7u3la.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0013\\out0GenericAffine.mat']
# 0.005324779
# ['2', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmp_bzkqovm.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0000\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0001\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0002\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0003\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0004\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0005\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0006\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0007\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0008\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0009\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0010\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0011\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0012\\out0GenericAffine.mat', 'C:\\Users\\cvzad\\AppData\\Local\\Temp\\tmpq0xhr_l_\\img0013\\out0GenericAffine.mat']
# 0.0030948427

# %%
T2w_template_mice_sl5.plot()

# %%
corrected_template_sl2_name = "C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl2_corrected.nii.gz"
corrected_template_sl3_name = "C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl3_corrected.nii.gz"
corrected_template_sl5_name = "C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl5_corrected.nii.gz"

T2w_template_mice_sl2.image_write(corrected_template_sl2_name)
T2w_template_mice_sl3.image_write(corrected_template_sl3_name)
T2w_template_mice_sl5.image_write(corrected_template_sl5_name)

# %%
########### DOWNSIZE TEMPLATE TO MATCH OUR MAPS ###################################



def resample_img(itk_image, out_size=[128, 128], is_label=False):
    
    # Resample images to 2mm spacing with SimpleITK
    original_spacing = itk_image.GetSpacing() # tamaño físico de un voxel en cada dimensión (mm/pixel)
    original_size = itk_image.GetSize() # # de voxels en cada eje
    out_size = out_size+list(original_size[2:]) # el tamaño sera [128,128,z...] z = tamaño de dimensión
                                                # z si es que la imagen es de tres dimensiones (se conserva)
    print(original_size)
    print(original_spacing)
    print(out_size)

    out_spacing = [
        original_size[0] * original_spacing[0] / out_size[0],
        original_size[1] * original_spacing[1] / out_size[1],
        # original_size[2] * original_spacing[2] / out_size[2]
    ]

    resample = sitk.ResampleImageFilter()
    resample.SetOutputSpacing(out_spacing)
    resample.SetSize(out_size)
    resample.SetOutputDirection(itk_image.GetDirection())
    resample.SetOutputOrigin(itk_image.GetOrigin())
    resample.SetTransform(sitk.Transform())
    resample.SetDefaultPixelValue(itk_image.GetPixelIDValue())

    if is_label:
        resample.SetInterpolator(sitk.sitkNearestNeighbor)
    else:
        resample.SetInterpolator(sitk.sitkBSpline)

    return resample.Execute(itk_image)

# %%
resampled_template_sl2_name = "C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl2_corrected_scaled.nii.gz"
itk_img = sitk.ReadImage(corrected_template_sl2_name)
resampled_img = resample_img(itk_img, out_size=[128, 128], is_label=False)
sitk.WriteImage(resampled_img,resampled_template_sl2_name)
# Out:
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]

# %%
resampled_template_sl3_name = "C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl3_corrected_scaled.nii.gz"
itk_img = sitk.ReadImage(corrected_template_sl3_name)
resampled_img = resample_img(itk_img, out_size=[128, 128], is_label=False)
sitk.WriteImage(resampled_img,resampled_template_sl3_name)
# Out:
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]

# %%
resampled_template_sl5_name = "C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl5_corrected_scaled.nii.gz"
itk_img = sitk.ReadImage(corrected_template_sl5_name)
resampled_img = resample_img(itk_img, out_size=[128, 128], is_label=False)
sitk.WriteImage(resampled_img,resampled_template_sl5_name)
# Out:
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]

# %%
############### CORREGISTER T2W IMAGES AND EXTRAPOLATE TO MAPS #################################

# Templates
# plantilla base:
T2w_template_mice_sl3_path = r"C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl3_corrected.nii.gz"
# plantilla reescalada
SCALED_T2w_template_mice_sl3_path = r"C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl3_corrected_scaled.nii.gz"
root_dir = r"C:/Users/cvzad/Documents/CirugiaBariatrica/"

template = ants.image_read(T2w_template_mice_sl3_path)
template_scaled = ants.image_read(SCALED_T2w_template_mice_sl3_path)


pattern = os.path.join(root_dir, '**', 'sourcedata', '**', 'anat', '*T2w_masked.nii.gz')
T2w_files = [f for f in glob.glob(pattern, recursive=True) if "corregistered_sl3_final_test" not in f]

# Iterar sobre cada T2w encontrado
for t2w_filename in T2w_files:
    print(f"\n Procesando: {t2w_filename}")

    # Extraer ID del sujeto desde el nombre del archivo 
    try:
        subject_id = [part for part in os.path.basename(t2w_filename).split("_") if part.startswith("sub-")][0]
    except IndexError:
        print(f" No se pudo extraer subject_id de: {t2w_filename}")
        continue

    anat_dir = os.path.dirname(t2w_filename)
    sourcedata_dir = os.path.abspath(os.path.join(anat_dir, "..", ".."))
    resomapper_output_dir = os.path.abspath(os.path.join(sourcedata_dir, ".."))
    derivatives_dir = os.path.join(resomapper_output_dir, "derivatives")

    # Crear carpeta de salida
    corregistered_sl3_dir = os.path.join(resomapper_output_dir, "corregistered_sl3_final_test")
    os.makedirs(corregistered_sl3_dir, exist_ok=True)

    # Leer la imagen T2w y extraer slice 3 
    t2w_img_full = ants.image_read(t2w_filename)

    t2w_slice3 = t2w_img_full[:, :, 2]  

    # Registrar la slice 3 al template
    transformation = ants.registration(fixed=template, moving=t2w_slice3)

    # Guardar imagen T2 registrada
    t2w_out_path = os.path.join(corregistered_sl3_dir, os.path.basename(t2w_filename))
    transformation["warpedmovout"].image_write(t2w_out_path)

    # Mapas a buscar
    map_types = ["MTR", "FA", "AD", "RD", "MD"]

    for map_type in map_types:
        map_pattern = os.path.join(derivatives_dir, "**", f"*{map_type}-processedmap.nii.gz")
        map_files = glob.glob(map_pattern, recursive=True)
        map_files = [f for f in map_files if subject_id in os.path.basename(f)]

        if not map_files:
            print(f"No se encontró mapa {map_type} para: {subject_id}")
            continue

        for map_file in map_files:
            print(f" Registrando mapa {map_type}: {map_file}")
            map_img_full = ants.image_read(map_file)

            map_slice3 = map_img_full[:, :, 2]

            corregistered_map = ants.apply_transforms(
                moving=map_slice3,
                fixed=template_scaled,
                transformlist=transformation["fwdtransforms"]
            )

            output_map_path = os.path.join(corregistered_sl3_dir, os.path.basename(map_file))
            corregistered_map.image_write(output_map_path)
# Out:
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R109\resomapper\sourcedata\sub-A090425_R109_CirugiaBar_Post_6w_090425\anat\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\MTR\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-5_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R110\resomapper_output\sourcedata\Post6w_270325\anat\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\MTR map_acq-4_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-4_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R111\resomapper_output\sourcedata\sub-E270325_R111_CirugiaBar_Post6w_270325\anat\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\MTR map_acq-5_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-5_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R112\resomapper_output\sourcedata\sub-F270325_R112_CirugiaBar_Post6w_270325\anat\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-2_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\derivatives\Post6w_270325\MTR map_acq-3_sub-F270325_R112_CirugiaBar_Post6w_270325\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-3_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\derivatives\Post6w_270325\DTI_acq-8_sub-F270325_R112_CirugiaBar_Post6w_270325\sub-F270325_R112_CirugiaBar_Post6w_270325_acq-8_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R112\resomapper_output\derivatives\Post6w_270325\DTI_acq-8_sub-F270325_R112_CirugiaBar_Post6w_270325\sub-F270325_R112_CirugiaBar_Post6w_270325_acq
run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\MTR map_acq-12_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-12_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Pre\R160\resomapper_output\sourcedata\sub-A030225_R160_CirugiaBar_Pre_030225\anat\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\MTR map_acq-9_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-9_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz

# %%
# Templates
# plantilla base:
T2w_template_mice_sl2_path = r"C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl2_corrected.nii.gz"
# plantilla reescalada
SCALED_T2w_template_mice_sl2_path = r"C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl2_corrected_scaled.nii.gz"
root_dir = r"C:/Users/cvzad/Documents/CirugiaBariatrica/"

template = ants.image_read(T2w_template_mice_sl2_path)
template_scaled = ants.image_read(SCALED_T2w_template_mice_sl2_path)


pattern = os.path.join(root_dir, '**', 'sourcedata', '**', 'anat', '*T2w_masked.nii.gz')
T2w_files = [f for f in glob.glob(pattern, recursive=True) if "corregistered_sl2_final_test" not in f]

# Iterar sobre cada T2w encontrado
for t2w_filename in T2w_files:
    print(f"\n Procesando: {t2w_filename}")

    # Extraer ID del sujeto desde el nombre del archivo 
    try:
        subject_id = [part for part in os.path.basename(t2w_filename).split("_") if part.startswith("sub-")][0]
    except IndexError:
        print(f" No se pudo extraer subject_id de: {t2w_filename}")
        continue

    anat_dir = os.path.dirname(t2w_filename)
    sourcedata_dir = os.path.abspath(os.path.join(anat_dir, "..", ".."))
    resomapper_output_dir = os.path.abspath(os.path.join(sourcedata_dir, ".."))
    derivatives_dir = os.path.join(resomapper_output_dir, "derivatives")

    # Crear carpeta de salida
    corregistered_sl2_dir = os.path.join(resomapper_output_dir, "corregistered_sl2_final_test")
    os.makedirs(corregistered_sl2_dir, exist_ok=True)

    # Leer la imagen T2w y extraer slice 2 
    t2w_img_full = ants.image_read(t2w_filename)

    t2w_slice2 = t2w_img_full[:, :, 2]  

    # Registrar la slice 2 al template
    transformation = ants.registration(fixed=template, moving=t2w_slice2)

    # Guardar imagen T2 registrada
    t2w_out_path = os.path.join(corregistered_sl2_dir, os.path.basename(t2w_filename))
    transformation["warpedmovout"].image_write(t2w_out_path)

    # Mapas a buscar
    map_types = ["MTR", "FA", "AD", "RD", "MD"]

    for map_type in map_types:
        map_pattern = os.path.join(derivatives_dir, "**", f"*{map_type}-processedmap.nii.gz")
        map_files = glob.glob(map_pattern, recursive=True)
        map_files = [f for f in map_files if subject_id in os.path.basename(f)]

        if not map_files:
            print(f"No se encontró mapa {map_type} para: {subject_id}")
            continue

        for map_file in map_files:
            print(f" Registrando mapa {map_type}: {map_file}")
            map_img_full = ants.image_read(map_file)

            map_slice2 = map_img_full[:, :, 1]

            corregistered_map = ants.apply_transforms(
                moving=map_slice2,
                fixed=template_scaled,
                transformlist=transformation["fwdtransforms"]
            )

            output_map_path = os.path.join(corregistered_sl2_dir, os.path.basename(map_file))
            corregistered_map.image_write(output_map_path)
# Out:
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R109\resomapper\sourcedata\sub-A090425_R109_CirugiaBar_Post_6w_090425\anat\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\MTR\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-5_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R110\resomapper_output\sourcedata\Post6w_270325\anat\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\MTR map_acq-4_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-4_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R111\resomapper_output\sourcedata\sub-E270325_R111_CirugiaBar_Post6w_270325\anat\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\MTR map_acq-5_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-5_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output\derivatives\Post6w_270325\DTI_acq-10_sub-E270325_R111_CirugiaBar_Post6w_270325\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-10_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\
run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\derivatives\Pre_270125\DTI_acq-9_sub-C270125_R113_CirugiaBar_Pre_270125\sub-C270125_R113_CirugiaBar_Pre_270125_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R113\resomapper_output\derivatives\Pre_270125\DTI_acq-9_sub-C270125_R113_CirugiaBar_Pre_270125\sub-C270125_R113_CirugiaBar_Pre_270125_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Pre\R159\resomapper_output\sourcedata\sub-D270125_R159_CirugiaBar_Pre_270125\anat\sub-D270125_R159_CirugiaBar_Pre_270125_acq-8_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\MTR map_acq-12_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-12_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R159\resomapper_output\derivatives\Pre_270125\DTI_acq-11_sub-D270125_R159_CirugiaBar_Pre_270125\sub-D270125_R159_CirugiaBar_Pre_270125_acq-11_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Pre\R160\resomapper_output\sourcedata\sub-A030225_R160_CirugiaBar_Pre_030225\anat\sub-A030225_R160_CirugiaBar_Pre_030225_acq-5_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\MTR map_acq-9_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-9_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz

# %%
# Templates
# plantilla base:
T2w_template_mice_sl5_path = r"C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl5_corrected.nii.gz"
# plantilla reescalada
SCALED_T2w_template_mice_sl5_path = r"C:/Users/cvzad/Documents/CirugiaBariatrica/Template_sl5_corrected_scaled.nii.gz"
root_dir = r"C:/Users/cvzad/Documents/CirugiaBariatrica/"

template = ants.image_read(T2w_template_mice_sl5_path)
template_scaled = ants.image_read(SCALED_T2w_template_mice_sl5_path)


pattern = os.path.join(root_dir, '**', 'sourcedata', '**', 'anat', '*T2w_masked.nii.gz')
T2w_files = [f for f in glob.glob(pattern, recursive=True) if "corregistered_sl5_final_test" not in f]

# Iterar sobre cada T2w encontrado
for t2w_filename in T2w_files:
    print(f"\n Procesando: {t2w_filename}")

    # Extraer ID del sujeto desde el nombre del archivo 
    try:
        subject_id = [part for part in os.path.basename(t2w_filename).split("_") if part.startswith("sub-")][0]
    except IndexError:
        print(f" No se pudo extraer subject_id de: {t2w_filename}")
        continue

    anat_dir = os.path.dirname(t2w_filename)
    sourcedata_dir = os.path.abspath(os.path.join(anat_dir, "..", ".."))
    resomapper_output_dir = os.path.abspath(os.path.join(sourcedata_dir, ".."))
    derivatives_dir = os.path.join(resomapper_output_dir, "derivatives")

    # Crear carpeta de salida
    corregistered_sl5_dir = os.path.join(resomapper_output_dir, "corregistered_sl5_final_test")
    os.makedirs(corregistered_sl5_dir, exist_ok=True)

    # Leer la imagen T2w y extraer slice 5 
    t2w_img_full = ants.image_read(t2w_filename)

    t2w_slice5 = t2w_img_full[:, :, 4]  

    # Registrar la slice 5 al template
    transformation = ants.registration(fixed=template, moving=t2w_slice5)

    # Guardar imagen T2 registrada
    t2w_out_path = os.path.join(corregistered_sl5_dir, os.path.basename(t2w_filename))
    transformation["warpedmovout"].image_write(t2w_out_path)

    # Mapas a buscar
    map_types = ["MTR", "FA", "AD", "RD", "MD"]

    for map_type in map_types:
        map_pattern = os.path.join(derivatives_dir, "**", f"*{map_type}-processedmap.nii.gz")
        map_files = glob.glob(map_pattern, recursive=True)
        map_files = [f for f in map_files if subject_id in os.path.basename(f)]

        if not map_files:
            print(f"No se encontró mapa {map_type} para: {subject_id}")
            continue

        for map_file in map_files:
            print(f" Registrando mapa {map_type}: {map_file}")
            map_img_full = ants.image_read(map_file)

            map_slice5 = map_img_full[:, :, 2]

            corregistered_map = ants.apply_transforms(
                moving=map_slice5,
                fixed=template_scaled,
                transformlist=transformation["fwdtransforms"]
            )

            output_map_path = os.path.join(corregistered_sl5_dir, os.path.basename(map_file))
            corregistered_map.image_write(output_map_path)
# Out:
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R109\resomapper\sourcedata\sub-A090425_R109_CirugiaBar_Post_6w_090425\anat\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-4_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\MTR\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-5_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R109\resomapper\derivatives\sub-A090425_R109_CirugiaBar_Post_6w_090425\DTI\sub-A090425_R109_CirugiaBar_Post_6w_090425_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R110\resomapper_output\sourcedata\Post6w_270325\anat\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-3_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\MTR map_acq-4_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-4_run-2_preproc_MTR-processedmap.nii.gz
#  Registrando mapa FA: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-FA-processedmap.nii.gz
#  Registrando mapa AD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R110\resomapper_output\derivatives\Post6w_270325\DTI_acq-9_sub-D270325_R110_CirugiaBar_Post6w_270325\sub-D270325_R110_CirugiaBar_Post6w_270325_acq-9_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz
#
#  Procesando: C:/Users/cvzad/Documents/CirugiaBariatrica\Post_6weeks\R111\resomapper_output\sourcedata\sub-E270325_R111_CirugiaBar_Post6w_270325\anat\sub-E270325_R111_CirugiaBar_Post6w_270325_acq-4_run-1_T2w_masked.nii.gz
#  Registrando mapa MTR: C:\Users\cvzad\Documents\CirugiaBariatrica\Post_6weeks\R111\resomapper_output
: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-AD-processedmap.nii.gz
#  Registrando mapa RD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-RD-processedmap.nii.gz
#  Registrando mapa MD: C:\Users\cvzad\Documents\CirugiaBariatrica\Pre\R160\resomapper_output\derivatives\Pre_030225\DTI_acq-8_sub-A030225_R160_CirugiaBar_Pre_030225\sub-A030225_R160_CirugiaBar_Pre_030225_acq-8_run-1_dwi_preproc_DTI-MD-processedmap.nii.gz

# %%
img = ants.image_read(t2w_filename)
print(img.shape)
# Out:
# (256, 256, 5)

# %%
# GROUP T2W AND MAPS IN ONE FILE

root_path =  r"C:/Users/cvzad/Documents/CirugiaBariatrica/"
# Grupos temporales
for group in ["Pre", "Post_6weeks"]:
    group_path = os.path.join(root_path, group)
    for subject in os.listdir(group_path):
        if subject.startswith("."):
            continue

        try:
            subject_path = glob.glob(os.path.join(group_path, subject, '**', 'corregistered_sl3_final_test'), recursive=True)[0]
        except IndexError:
            print(f" No se encontró carpeta corregistered_sl3_final_test para {subject}")
            continue

        print(f" Agrupando mapas de: {group} / {subject}")

        # Obtener T2w
        try:
            t2w_pre = glob.glob(os.path.join(subject_path, "*T2w_masked.nii.gz"))[0]
        except IndexError:
            print(f"T2w no encontrado para {subject}")
            continue

        t2w_post = t2w_pre.replace(".nii.gz", "_scaled.nii.gz")

        # Reescalar y guardar
        itk_img = sitk.ReadImage(t2w_pre)
        resampled_img = resample_img(itk_img, out_size=[128, 128], is_label=False)
        sitk.WriteImage(resampled_img, t2w_post)

        # Cargar mapas (ordenados)
        try:
            mtr_map = glob.glob(os.path.join(subject_path, "*MTR-processedmap.nii.gz"))[0]
            ad_map  = glob.glob(os.path.join(subject_path, "*AD-processedmap.nii.gz"))[0]
            fa_map  = glob.glob(os.path.join(subject_path, "*FA-processedmap.nii.gz"))[0]
            rd_map  = glob.glob(os.path.join(subject_path, "*RD-processedmap.nii.gz"))[0]
            md_map  = glob.glob(os.path.join(subject_path, "*MD-processedmap.nii.gz"))[0]
        except IndexError:
            print(f" Faltan uno o más mapas en {subject_path}, se omite.")
            continue

        map_files = [t2w_post, mtr_map, ad_map, fa_map, md_map, rd_map]
        images = []
        ref_affine = None

        for i, file in enumerate(map_files):
            img = nib.load(file)
            data = img.get_fdata()

            if data.ndim == 3:
                data = data[:, :, 0]  # Asegurar que sea 2D
            images.append(data)

            if ref_affine is None:
                ref_affine = img.affine

        # Apilar a lo largo del eje Z (canal)
        stacked_images = np.stack(images, axis=-1)

        # Guardar imagen apilada
        out_nifti = nib.Nifti1Image(stacked_images, ref_affine)
        out_filename = f"{subject}_sl3_maps.nii.gz"
        nib.save(out_nifti, os.path.join(subject_path, out_filename))
        print(f" Guardado: {out_filename}")
# Out:
#  Agrupando mapas de: Pre / R109
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R109_sl3_maps.nii.gz
#  Agrupando mapas de: Pre / R110
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R110_sl3_maps.nii.gz
#  Agrupando mapas de: Pre / R111
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R111_sl3_maps.nii.gz
#  Agrupando mapas de: Pre / R112
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R112_sl3_maps.nii.gz
#  Agrupando mapas de: Pre / R113
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R113_sl3_maps.nii.gz
#  Agrupando mapas de: Pre / R159
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R159_sl3_maps.nii.gz
#  Agrupando mapas de: Pre / R160
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R160_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R109
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R109_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R110
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R110_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R111
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R111_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R112
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R112_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R113
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R113_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R159
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R159_sl3_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R160
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R160_sl3_maps.nii.gz

# %%
# GROUP T2W AND MAPS IN ONE FILE

root_path =  r"C:/Users/cvzad/Documents/CirugiaBariatrica/"
# Grupos temporales
for group in ["Pre", "Post_6weeks"]:
    group_path = os.path.join(root_path, group)
    for subject in os.listdir(group_path):
        if subject.startswith("."):
            continue

        try:
            subject_path = glob.glob(os.path.join(group_path, subject, '**', 'corregistered_sl2_final_test'), recursive=True)[0]
        except IndexError:
            print(f" No se encontró carpeta corregistered_sl2_final_test para {subject}")
            continue

        print(f" Agrupando mapas de: {group} / {subject}")

        # Obtener T2w
        try:
            t2w_pre = glob.glob(os.path.join(subject_path, "*T2w_masked.nii.gz"))[0]
        except IndexError:
            print(f"T2w no encontrado para {subject}")
            continue

        t2w_post = t2w_pre.replace(".nii.gz", "_scaled.nii.gz")

        # Reescalar y guardar
        itk_img = sitk.ReadImage(t2w_pre)
        resampled_img = resample_img(itk_img, out_size=[128, 128], is_label=False)
        sitk.WriteImage(resampled_img, t2w_post)

        # Cargar mapas (ordenados)
        try:
            mtr_map = glob.glob(os.path.join(subject_path, "*MTR-processedmap.nii.gz"))[0]
            ad_map  = glob.glob(os.path.join(subject_path, "*AD-processedmap.nii.gz"))[0]
            fa_map  = glob.glob(os.path.join(subject_path, "*FA-processedmap.nii.gz"))[0]
            rd_map  = glob.glob(os.path.join(subject_path, "*RD-processedmap.nii.gz"))[0]
            md_map  = glob.glob(os.path.join(subject_path, "*MD-processedmap.nii.gz"))[0]
        except IndexError:
            print(f" Faltan uno o más mapas en {subject_path}, se omite.")
            continue

        map_files = [t2w_post, mtr_map, ad_map, fa_map, md_map, rd_map]
        images = []
        ref_affine = None

        for i, file in enumerate(map_files):
            img = nib.load(file)
            data = img.get_fdata()

            if data.ndim == 3:
                data = data[:, :, 0]  # Asegurar que sea 2D
            images.append(data)

            if ref_affine is None:
                ref_affine = img.affine

        # Apilar a lo largo del eje Z (canal)
        stacked_images = np.stack(images, axis=-1)

        # Guardar imagen apilada
        out_nifti = nib.Nifti1Image(stacked_images, ref_affine)
        out_filename = f"{subject}_sl2_maps.nii.gz"
        nib.save(out_nifti, os.path.join(subject_path, out_filename))
        print(f" Guardado: {out_filename}")
# Out:
#  Agrupando mapas de: Pre / R109
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R109_sl2_maps.nii.gz
#  Agrupando mapas de: Pre / R110
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R110_sl2_maps.nii.gz
#  Agrupando mapas de: Pre / R111
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R111_sl2_maps.nii.gz
#  Agrupando mapas de: Pre / R112
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R112_sl2_maps.nii.gz
#  Agrupando mapas de: Pre / R113
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R113_sl2_maps.nii.gz
#  Agrupando mapas de: Pre / R159
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R159_sl2_maps.nii.gz
#  Agrupando mapas de: Pre / R160
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R160_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R109
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R109_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R110
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R110_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R111
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R111_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R112
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R112_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R113
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R113_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R159
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R159_sl2_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R160
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R160_sl2_maps.nii.gz

# %%
# GROUP T2W AND MAPS IN ONE FILE

root_path =  r"C:/Users/cvzad/Documents/CirugiaBariatrica/"
# Grupos temporales
for group in ["Pre", "Post_6weeks"]:
    group_path = os.path.join(root_path, group)
    for subject in os.listdir(group_path):
        if subject.startswith("."):
            continue

        try:
            subject_path = glob.glob(os.path.join(group_path, subject, '**', 'corregistered_sl5_final_test'), recursive=True)[0]
        except IndexError:
            print(f" No se encontró carpeta corregistered_sl5_final_test para {subject}")
            continue

        print(f" Agrupando mapas de: {group} / {subject}")

        # Obtener T2w
        try:
            t2w_pre = glob.glob(os.path.join(subject_path, "*T2w_masked.nii.gz"))[0]
        except IndexError:
            print(f"T2w no encontrado para {subject}")
            continue

        t2w_post = t2w_pre.replace(".nii.gz", "_scaled.nii.gz")

        # Reescalar y guardar
        itk_img = sitk.ReadImage(t2w_pre)
        resampled_img = resample_img(itk_img, out_size=[128, 128], is_label=False)
        sitk.WriteImage(resampled_img, t2w_post)

        # Cargar mapas (ordenados)
        try:
            mtr_map = glob.glob(os.path.join(subject_path, "*MTR-processedmap.nii.gz"))[0]
            ad_map  = glob.glob(os.path.join(subject_path, "*AD-processedmap.nii.gz"))[0]
            fa_map  = glob.glob(os.path.join(subject_path, "*FA-processedmap.nii.gz"))[0]
            rd_map  = glob.glob(os.path.join(subject_path, "*RD-processedmap.nii.gz"))[0]
            md_map  = glob.glob(os.path.join(subject_path, "*MD-processedmap.nii.gz"))[0]
        except IndexError:
            print(f" Faltan uno o más mapas en {subject_path}, se omite.")
            continue

        map_files = [t2w_post, mtr_map, ad_map, fa_map, md_map, rd_map]
        images = []
        ref_affine = None

        for i, file in enumerate(map_files):
            img = nib.load(file)
            data = img.get_fdata()

            if data.ndim == 3:
                data = data[:, :, 0]  # Asegurar que sea 2D
            images.append(data)

            if ref_affine is None:
                ref_affine = img.affine

        # Apilar a lo largo del eje Z (canal)
        stacked_images = np.stack(images, axis=-1)

        # Guardar imagen apilada
        out_nifti = nib.Nifti1Image(stacked_images, ref_affine)
        out_filename = f"{subject}_sl5_maps.nii.gz"
        nib.save(out_nifti, os.path.join(subject_path, out_filename))
        print(f" Guardado: {out_filename}")
# Out:
#  Agrupando mapas de: Pre / R109
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R109_sl5_maps.nii.gz
#  Agrupando mapas de: Pre / R110
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R110_sl5_maps.nii.gz
#  Agrupando mapas de: Pre / R111
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R111_sl5_maps.nii.gz
#  Agrupando mapas de: Pre / R112
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R112_sl5_maps.nii.gz
#  Agrupando mapas de: Pre / R113
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R113_sl5_maps.nii.gz
#  Agrupando mapas de: Pre / R159
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R159_sl5_maps.nii.gz
#  Agrupando mapas de: Pre / R160
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R160_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R109
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R109_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R110
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R110_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R111
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R111_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R112
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R112_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R113
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R113_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R159
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R159_sl5_maps.nii.gz
#  Agrupando mapas de: Post_6weeks / R160
# (256, 256)
# (0.08203125, 0.08203125)
# [128, 128]
#  Guardado: R160_sl5_maps.nii.gz

# %% [markdown]
# # Displacement

# %%
def visualize_transformation(fixed_image, moving_image, warped_image, registration_result):
    try:
        # Convertir a arrays
        fixed_arr = fixed_image.numpy()
        moving_arr = moving_image.numpy()
        warped_arr = warped_image.numpy()

        # Si son imágenes 3D, extrae el slice axial (índice 2)
        slice_index = 2
        if fixed_arr.ndim == 3:
            fixed_arr = fixed_arr[:, :, slice_index]
        if moving_arr.ndim == 3:
            moving_arr = moving_arr[:, :, slice_index]
        if warped_arr.ndim == 3:
            warped_arr = warped_arr[:, :, slice_index]

        # Leer campo de deformación
        warp_field_path = registration_result["fwdtransforms"][0]
        warp_field = ants.image_read(warp_field_path)
        warp_array = warp_field.numpy()  # Dimensiones: (X, Y, 2)

        # Extraer componentes del vector desplazamiento (ya 2D)
        dx = warp_array[:, :, 0]
        dy = warp_array[:, :, 1]

        # Crear grilla de puntos
        x = np.arange(0, dx.shape[1], 5)
        y = np.arange(0, dx.shape[0], 5)
        X, Y = np.meshgrid(x, y)

        # Submuestreo de los vectores
        U = dx[Y, X]
        V = dy[Y, X]

        # Visualización
        fig, axs = plt.subplots(1, 4, figsize=(20, 5))

        axs[0].imshow(fixed_arr, cmap="gray")
        axs[0].set_title("Fixed image (Template)")
        axs[0].axis("off")

        axs[1].imshow(moving_arr, cmap="gray")
        axs[1].set_title("Moving image (Before registration)")
        axs[1].axis("off")

        axs[2].imshow(warped_arr, cmap="gray")
        axs[2].set_title("Warped image (After registration)")
        axs[2].axis("off")

        axs[3].imshow(fixed_arr, cmap="gray")
        axs[3].quiver(X, Y, U, V, color="red", angles="xy", scale_units="xy", scale=1)
        axs[3].set_title("Deformation field")
        axs[3].axis("off")

        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error: {e}")

# %%
conditions = ["Pre", "Post_6weeks"]
root_path =  r"C:/Users/cvzad/Documents/CirugiaBariatrica/"
T2w_template_path = os.path.join(root_path, "Template_sl3_corrected.nii.gz")
T2w_template = ants.image_read(T2w_template_path)

subject = "R112"
registration_results = {}

for group in ["Pre", "Post_6weeks"]:
    group_path = os.path.join(root_path, group, subject, "resomapper_output", "corregistered_sl3_final_test")

    try:
        t2w_candidates = glob.glob(os.path.join(group_path, "*T2w_masked.nii.gz")) # solo devuelve uno pero lo hace en forma de lista
    except IndexError:
        print(f"T2w no encontrado para {group, subject}")
        continue
    t2w_path = t2w_candidates[0]
    
    t2w = ants.image_read(t2w_path)
    
    registration_results[group] = ants.registration(fixed= T2w_template, moving= t2w, type_of_transform= "SyN")
    
    visualize_transformation(fixed_image= T2w_template, moving_image= t2w, 
                             warped_image= registration_results[group]['warpedmovout'], 
                             registration_result= registration_results[group])
